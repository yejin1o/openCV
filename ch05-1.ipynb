# %%
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img1 = cv2.imread('/content/gdrive/My Drive/ColabIP/lena256.jpg')
RGB_img = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

gImg = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gImg.shape)
cv2_imshow(gImg)
#plt.imshow(gImg1, cmap='gray')
# Out:
# (256, 256)
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel3 = np.ones((3, 3), np.float32)/9
kernel5 = np.ones((5, 5), np.float32)/25

# %%
kernel3[0][0] = 1/9
kernel3[0][1] = 1/9
kernel3[0][2] = 1/9
kernel3[1][0] = 1/9
kernel3[1][1] = 1/9
kernel3[1][2] = 1/9
kernel3[2][0] = 1/9
kernel3[2][1] = 1/9
kernel3[2][2] = 1/9

# %%
outImg3 = cv2.filter2D(gImg, -1, kernel3)
cv2_imshow(outImg3)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
outImg3 = cv2.filter2D(gImg, -1, kernel3)
cv2_imshow(outImg3)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
outImg5 = cv2.filter2D(gImg, -1, kernel5)
cv2_imshow(outImg5)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
outImg33 = cv2.filter2D(outImg3, -1, kernel3)
cv2_imshow(outImg33)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
outImg333 = cv2.filter2D(outImg33, -1, kernel3)
cv2_imshow(outImg333)
# Out:
# <PIL.Image.Image image mode=L size=256x256>
